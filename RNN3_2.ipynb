# %%
import pandas as pd
import numpy as np
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# to be able to use .head(100) to see more rows of df
pd.set_option("display.max_rows", 100, "display.max_columns", None)
pd.set_option('use_inf_as_na', True)

# %%
# read the data
df = pd.read_csv('dataset_mood_smartphone.csv', index_col=0)

# get dates from timestamp
df['time']= pd.to_datetime(df['time'])
df['date'] = df['time'].dt.date

# %% [markdown]
# # Feature Engineering setup

# %%
# find week with most mood values per user and number of mood values of the next day
def define_dates(df, interval):
    data = df.copy()
    data['date'] = pd.to_datetime(data['date'])
    users = data['id'].unique()
    dates = []
    next_date_entries = []
    
    for user in users:
        attempt = 0
        weeks = data[(data['id'] == user) & (data['variable'] == 'mood')].groupby(['id', pd.Grouper(key='date', freq='W-MON')])['value'].sum().sort_values(ascending=False).index
        date = weeks[0]
        next_date_entry = data[(data['date'] == date[1] + pd.Timedelta(days=interval)) & (data['variable'] == 'mood') & (data['id'] == user)]['value'].count()
        penultimate_entry = data[(data['date'] == date[1] + pd.Timedelta(days=interval-1)) & (data['variable'] == 'mood') & (data['id'] == user)]['value'].count()
        
        while next_date_entry == 0 or penultimate_entry == 0:
            attempt += 1
            date = weeks[attempt]
            next_date_entry = data[(data['date'] == date[1] + pd.Timedelta(days=interval)) & (data['variable'] == 'mood') & (data['id'] == user)]['value'].count()
            penultimate_entry = data[(data['date'] == date[1] + pd.Timedelta(days=interval-1)) & (data['variable'] == 'mood') & (data['id'] == user)]['value'].count()

        
        dates.append(date)
        next_date_entries.append(next_date_entry)
    return dates, next_date_entries

dates, next_date_entries = define_dates(df, 7)

# %%
def define_weights(df, dates):
    data = df.copy()
    weight_per_user = []
    
    for tup in dates:
        user = tup[0]
        date = tup[1].date()
        weight = 1
        for i in range(7):
            day = date + pd.Timedelta(days=i) 
            weight *= 1.4
            weight_per_user.append({'id':user, 'time':pd.Timestamp(day) , 'date':day, 'variable':'weight', 'value': int(weight)})
        
    return weight_per_user

# %%
# add weight to df
weight_per_user = define_weights(df, dates)
df = df.append(pd.DataFrame(weight_per_user))

# %%
def sleep_calculation(df):
    data = df.copy()
    sleep_per_user = []
    
    # iterate over unique users
    for user in data['id'].unique():

        # gather user's data
        df_user = data[data['id'] == user]

        # iterate over unique dates
        for day in pd.to_datetime(df_user["time"]).map(pd.Timestamp.date).unique():
#             print(day)

            # define start and end of the night
            start_night = pd.Timestamp(day) - pd.Timedelta(3, 'h')
            end_night = pd.Timestamp(day) + pd.Timedelta(9, 'h')
            
            # get all the times of measurements during the night
            time_deltas = df_user[(df_user['time'] >= start_night) & (df_user['time'] < end_night)]['time'].values

            # calculate sleep as the largest interval between measurements, if more than one measurement
            if len(time_deltas) > 1:
                sleep = int(max(abs(x - y) for (x, y) in zip(time_deltas[1:], time_deltas[:-1])) / np.timedelta64(1, 'h'))

            # otherwise, set sleep to 12 (changeable)
            else:
                sleep = 12

            sleep_per_user.append({'id':user, 'time':pd.Timestamp(day), 'date':day, 'variable':'sleep', 'value': sleep})
            
    return sleep_per_user

# %%
# add sleep to df
sleep_per_user = sleep_calculation(df)
df = df.append(pd.DataFrame(sleep_per_user))

# %%
# turn 'variable' into separate columns, taking sum of values per day per user
df_sum = df.groupby(['id', 'date', 'variable'])['value'].sum().unstack()

# turn 'variable' into separate columns, taking mean of values per day per user
df_mean = df.groupby(['id', 'date', 'variable'])['value'].mean().unstack()

# %%
# combine mean of score values and sum of time values into one dataframe
df_combi = df_sum
df_combi['mood'] = df_mean['mood']
df_combi['circumplex.arousal'] = df_mean['circumplex.arousal']
df_combi['circumplex.valence'] = df_mean['circumplex.valence']
df_combi['activity'] = df_mean['activity']
df_combi['weight'] = df_combi['weight'].fillna(0).sort_values()
df_combi.columns.name = None

# %%
df_to_rol = df_combi.reset_index(level='id')
df_rolled = df_to_rol.groupby('id').rolling(7, min_periods=5).mean()
df_rolled['mean_mood'] = df_mean['mood']

# %%
df_rolled = df_rolled.dropna(axis = 0, how = 'all')
df_rolled = df_rolled.dropna(subset=['mood','screen'], how='all')
df_rolled = df_rolled.reset_index(level='id')
df_rolled = df_rolled.reset_index(level='date')

# %%
# determine whether date is a weekend day or not
def weekend(df):
    data = df.copy()
    weekend_bools = {}
    
    # iterate over unique dates
    for date in data['date'].unique():
        
        # check day of the week (5 and 6 are saturday and sunday)
        if date.weekday() > 4:
            weekend_bools[date] = 1
        else:
            weekend_bools[date] = 0
            
    return weekend_bools

# %%
# add weekend bools to df
weekend_bools = weekend(df_rolled)
df_rolled['weekend'] = df_rolled['date'].map(weekend_bools)

# %%
def geneva_emo_wheel(df):
    for index, row in df.iterrows():
        #neutral
        if 0 == row['circumplex.arousal'] and 0 == row['circumplex.valence']:
            df.loc[index, 'emo_wheel'] = 0
        
        #high arousal positive valance
        if 0 <= row['circumplex.arousal'] and 0 <= row['circumplex.valence']: 
            df.loc[index, 'emo_wheel'] = 1
         
        #low arousal positive valance    
        elif 0 >= row['circumplex.arousal'] and 0 <= row['circumplex.valence']: 
            df.loc[index, 'emo_wheel'] = 2
        
        #high arousal negative valance
        elif 0 <= row['circumplex.arousal'] and 0 >= row['circumplex.valence']: 
            df.loc[index, 'emo_wheel'] = 3
       
        #low arousal negative valance
        elif 0 >= row['circumplex.arousal'] and 0 >= row['circumplex.valence']: 
            df.loc[index, 'emo_wheel'] = 4
        else:
             df.loc[index, 'emo_wheel'] = 0
    return df

# %%
df_rolled['emo_wheel'] = 0
df_rolled = geneva_emo_wheel(df_rolled)

# %%
corr = df_rolled[2:].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5ff3f_row0_col0, #T_5ff3f_row1_col1, #T_5ff3f_row2_col2, #T_5ff3f_row3_col3, #T_5ff3f_row4_col4, #T_5ff3f_row5_col5, #T_5ff3f_row6_col6, #T_5ff3f_row7_col7, #T_5ff3f_row8_col8, #T_5ff3f_row9_col9, #T_5ff3f_row10_col10, #T_5ff3f_row10_col19, #T_5ff3f_row11_col11, #T_5ff3f_row12_col12, #T_5ff3f_row13_col13, #T_5ff3f_row14_col14, #T_5ff3f_row15_col15, #T_5ff3f_row16_col16, #T_5ff3f_row17_col17, #T_5ff3f_row18_col18, #T_5ff3f_row19_col10, #T_5ff3f_row19_col19, #T_5ff3f_row20_col20, #T_5ff3f_row21_col21, #T_5ff3f_row22_col22, #T_5ff3f_row23_col23 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5ff3f_row0_col1, #T_5ff3f_row0_col9, #T_5ff3f_row14_col1, #T_5ff3f_row16_col20 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5ff3f_row0_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_5ff3f_row0_col3, #T_5ff3f_row1_col19, #T_5ff3f_row11_col13, #T_5ff3f_row18_col14, #T_5ff3f_row23_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_5ff3f_row0_col4, #T_5ff3f_row2_col8, #T_5ff3f_row13_col3, #T_5ff3f_row19_col22, #T_5ff3f_row23_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5ff3f_row0_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_5ff3f_row0_col6, #T_5ff3f_row1_col20, #T_5ff3f_row3_col9, #T_5ff3f_row7_col21, #T_5ff3f_row9_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5ff3f_row0_col7, #T_5ff3f_row10_col5, #T_5ff3f_row11_col18, #T_5ff3f_row16_col14, #T_5ff3f_row17_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5ff3f_row0_col8, #T_5ff3f_row5_col22, #T_5ff3f_row11_col22, #T_5ff3f_row14_col18, #T_5ff3f_row17_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5ff3f_row0_col10, #T_5ff3f_row5_col15, #T_5ff3f_row18_col23, #T_5ff3f_row19_col23, #T_5ff3f_row23_col19 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_5ff3f_row0_col11, #T_5ff3f_row1_col10 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5ff3f_row0_col12, #T_5ff3f_row15_col21, #T_5ff3f_row16_col7, #T_5ff3f_row17_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5ff3f_row0_col13, #T_5ff3f_row0_col19, #T_5ff3f_row10_col17, #T_5ff3f_row16_col6, #T_5ff3f_row18_col19 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_5ff3f_row0_col14, #T_5ff3f_row2_col3, #T_5ff3f_row3_col16, #T_5ff3f_row12_col17 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_5ff3f_row0_col15, #T_5ff3f_row2_col11, #T_5ff3f_row12_col23, #T_5ff3f_row21_col10, #T_5ff3f_row22_col10, #T_5ff3f_row23_col17 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5ff3f_row0_col16, #T_5ff3f_row5_col14, #T_5ff3f_row6_col16, #T_5ff3f_row9_col11, #T_5ff3f_row14_col15, #T_5ff3f_row16_col17, #T_5ff3f_row23_col11 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_5ff3f_row0_col17, #T_5ff3f_row17_col8, #T_5ff3f_row18_col17 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_5ff3f_row0_col18, #T_5ff3f_row2_col13, #T_5ff3f_row15_col23 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_5ff3f_row0_col20, #T_5ff3f_row3_col18, #T_5ff3f_row6_col7, #T_5ff3f_row6_col9, #T_5ff3f_row7_col18, #T_5ff3f_row10_col6, #T_5ff3f_row19_col15, #T_5ff3f_row19_col18, #T_5ff3f_row20_col0, #T_5ff3f_row20_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_5ff3f_row0_col21, #T_5ff3f_row5_col20, #T_5ff3f_row5_col21, #T_5ff3f_row13_col9, #T_5ff3f_row20_col15, #T_5ff3f_row22_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_5ff3f_row0_col22, #T_5ff3f_row3_col6, #T_5ff3f_row13_col21 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_5ff3f_row0_col23, #T_5ff3f_row16_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5ff3f_row1_col0, #T_5ff3f_row11_col6, #T_5ff3f_row13_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col2, #T_5ff3f_row13_col10, #T_5ff3f_row16_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_5ff3f_row1_col3, #T_5ff3f_row4_col20, #T_5ff3f_row7_col1, #T_5ff3f_row9_col12, #T_5ff3f_row9_col20, #T_5ff3f_row15_col13 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col4, #T_5ff3f_row1_col17, #T_5ff3f_row8_col19, #T_5ff3f_row9_col19, #T_5ff3f_row15_col2, #T_5ff3f_row17_col19, #T_5ff3f_row23_col18 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5ff3f_row1_col5, #T_5ff3f_row2_col1, #T_5ff3f_row3_col11, #T_5ff3f_row23_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col6, #T_5ff3f_row23_col15 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col7, #T_5ff3f_row18_col10, #T_5ff3f_row21_col17 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5ff3f_row1_col8, #T_5ff3f_row11_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_5ff3f_row1_col9, #T_5ff3f_row20_col19, #T_5ff3f_row22_col5, #T_5ff3f_row22_col11 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5ff3f_row1_col11, #T_5ff3f_row1_col12, #T_5ff3f_row8_col17 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_5ff3f_row1_col13, #T_5ff3f_row11_col17, #T_5ff3f_row15_col0, #T_5ff3f_row20_col11, #T_5ff3f_row21_col13, #T_5ff3f_row21_col23 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_5ff3f_row1_col14, #T_5ff3f_row7_col23 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5ff3f_row1_col15, #T_5ff3f_row9_col2, #T_5ff3f_row15_col1, #T_5ff3f_row19_col17 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col16, #T_5ff3f_row2_col14, #T_5ff3f_row17_col14, #T_5ff3f_row22_col17 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5ff3f_row1_col18, #T_5ff3f_row2_col18 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_5ff3f_row1_col21, #T_5ff3f_row7_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col22, #T_5ff3f_row3_col22 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5ff3f_row1_col23, #T_5ff3f_row9_col18, #T_5ff3f_row16_col19, #T_5ff3f_row21_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5ff3f_row2_col0, #T_5ff3f_row4_col7, #T_5ff3f_row4_col9, #T_5ff3f_row21_col15 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_5ff3f_row2_col4, #T_5ff3f_row6_col10, #T_5ff3f_row14_col19 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5ff3f_row2_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_5ff3f_row2_col6, #T_5ff3f_row4_col6, #T_5ff3f_row4_col13, #T_5ff3f_row7_col16, #T_5ff3f_row9_col10, #T_5ff3f_row10_col23, #T_5ff3f_row13_col19, #T_5ff3f_row16_col18, #T_5ff3f_row23_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_5ff3f_row2_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_5ff3f_row2_col9, #T_5ff3f_row3_col20, #T_5ff3f_row9_col16, #T_5ff3f_row11_col15, #T_5ff3f_row22_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col10, #T_5ff3f_row3_col17, #T_5ff3f_row21_col5, #T_5ff3f_row23_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5ff3f_row2_col12, #T_5ff3f_row4_col5, #T_5ff3f_row10_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col15, #T_5ff3f_row10_col0, #T_5ff3f_row15_col18, #T_5ff3f_row18_col4, #T_5ff3f_row19_col9, #T_5ff3f_row20_col1, #T_5ff3f_row21_col18 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5ff3f_row2_col16, #T_5ff3f_row17_col16 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_5ff3f_row2_col17, #T_5ff3f_row12_col15 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col19, #T_5ff3f_row5_col3, #T_5ff3f_row6_col8, #T_5ff3f_row10_col14 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5ff3f_row2_col20, #T_5ff3f_row13_col1, #T_5ff3f_row22_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col21, #T_5ff3f_row3_col0, #T_5ff3f_row22_col1, #T_5ff3f_row22_col3, #T_5ff3f_row22_col21 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col22, #T_5ff3f_row13_col22 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5ff3f_row2_col23, #T_5ff3f_row17_col23 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_5ff3f_row3_col1, #T_5ff3f_row15_col20 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5ff3f_row3_col2, #T_5ff3f_row17_col11 {
#   background-color: #dbdcde;
#   color:

# %% [markdown]
# #### Atributes

# %%
attributes = ['id', 'date','mood','mean_mood','emo_wheel', 'appCat.weather', 'appCat.entertainment', 'activity', 'appCat.office']#

# %%
df_sub = df_rolled[attributes]

# %%
#drop empty mood and fil NaN with zero
df_sub = df_sub.dropna(subset=['mood'], how='all')
df_sub = df_sub.replace([np.inf, -np.inf],0)
df_sub = df_sub.fillna(0)

# %%
# Remove outliers by only keeping values within 3 mad from the median
for column in df_sub.columns.tolist()[2:]: 
    
    median = df_sub[column].median()
    mad = df_sub[column].mad()
    
    outliers = df_sub[(df_sub[column] >= median+(3*mad)) & (df_sub[column] <= median-(3*mad))][column]
    df_sub = df_sub.replace(to_replace=outliers, value=0)

# %%
# get days to predict per user
dates_to_predict = [(date[0], date[1].date() + pd.Timedelta(days=7)) for date in dates]
df_predict = pd.DataFrame()

# create dataframe for days to predict per user
for date in dates_to_predict:
    df_predict = df_predict.append(df_sub[(df_sub['id'] == date[0]) & (df_sub['date'] == date[1])])

df_sub = df_sub.append(df_predict.copy()).drop_duplicates(keep=False)

# one-hot encode user ids, normalize and fillna to get same shape as train df
df_predict = df_predict.drop(['date'],axis = 1)
df_predict =  pd.get_dummies(df_predict, prefix='id')
df_predict = df_predict.fillna(0)

# define x and y for prediction
y_predict = df_predict['mood']
X_predict = df_predict.drop('mood', axis=1)
X_predict = (X_predict-X_predict.min())/(X_predict.max()-X_predict.min())
X_predict = X_predict.fillna(0)

# %%
df_sub = df_sub.drop(['date'],axis = 1)
#df_sub =  pd.get_dummies(df_sub, prefix='id')

# %%
for i in df_sub.columns.tolist()[1:]: #>>>> aangepast
    if not i in ['mood','mean_mood']:
        df_sub[i]=(df_sub[i]-df_sub[i].min())/(df_sub[i].max()-df_sub[i].min())

# %% [markdown]
# ## RNN Model

# %%
X_train_all =[]
X_test_all = []
X_val_all = []
y_train_all = []
y_test_all = []
y_val_all = []

X_test_user = []
y_test_user = []

for i in df.id.unique():
    dfid = df_sub[df_sub['id'] == i]
    mood_id = dfid[['mood','emo_wheel']].values.tolist()

    X = []
    y = []
    for j in range(21,len(mood_id)):
        X.append([val for val in mood_id[j-21:j]])
        y.append([mood_id[j][0]])
    
    len_1 = int(len(X) * 0.8)
    len_2 = int(len_1* 0.8)
    X_test_dfid = dfid.tail(len(X)-len_2)
    X_train_all.append(X[:len_2])
    X_val_all.append(X[len_2:len_1])
    X_test_all.append(X[len_1:])
    X_test_user.append({i:X[len_1:]})
    
    
    y_train_all.append(y[:len_2])
    y_val_all.append(y[len_2:len_1])
    y_test_all.append(y[len_1:])
    y_test_user.append({i:y[len_1:]})

# %%
def flatlist(list):
    flat_list = []
    for l in list:
        for item in l:
            flat_list.append(item)
    return flat_list

# %%
X_train_all = np.array(flatlist(X_train_all))
X_test_all = np.array(flatlist(X_test_all))
X_val_all = np.array(flatlist(X_val_all))
y_train_all = np.array(flatlist(y_train_all))
y_test_all = np.array(flatlist(y_test_all))
y_val_all = np.array(flatlist(y_val_all))

# %%
X_train_all.shape, X_test_all.shape, X_val_all.shape
# Out:
# ((352, 21, 2), (128, 21, 2), (105, 21, 2))

# %%
y_train_all.shape, y_test_all.shape, y_val_all.shape
# Out:
# ((352, 1), (128, 1), (105, 1))

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train_all.shape[1], X_train_all.shape[2])))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 21, 50)            10600
#
#  dropout (Dropout)           (None, 21, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
regressor.fit(X_train_all, y_train_all, epochs = 75, batch_size = 16, validation_data=(X_val_all, y_val_all))
# Out:
# Epoch 1/75
# 22/22 [==============================] - 3s 48ms/step - loss: 18.8513 - val_loss: 1.7154
# Epoch 2/75
# 22/22 [==============================] - 0s 14ms/step - loss: 0.9130 - val_loss: 0.4478
# Epoch 3/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6482 - val_loss: 0.2879
# Epoch 4/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.5784 - val_loss: 0.2657
# Epoch 5/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5741 - val_loss: 0.2645
# Epoch 6/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5474 - val_loss: 0.2643
# Epoch 7/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.5270 - val_loss: 0.2636
# Epoch 8/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5600 - val_loss: 0.2693
# Epoch 9/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5298 - val_loss: 0.2695
# Epoch 10/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.6037 - val_loss: 0.2619
# Epoch 11/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5870 - val_loss: 0.2747
# Epoch 12/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5380 - val_loss: 0.2558
# Epoch 13/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5878 - val_loss: 0.2534
# Epoch 14/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5692 - val_loss: 0.2531
# Epoch 15/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5404 - val_loss: 0.2618
# Epoch 16/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5865 - val_loss: 0.2443
# Epoch 17/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.5476 - val_loss: 0.2655
# Epoch 18/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.5143 - val_loss: 0.2382
# Epoch 19/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.5255 - val_loss: 0.2299
# Epoch 20/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4339 - val_loss: 0.2186
# Epoch 21/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5367 - val_loss: 0.2705
# Epoch 22/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4740 - val_loss: 0.2174
# Epoch 23/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4421 - val_loss: 0.1619
# Epoch 24/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4536 - val_loss: 0.2258
# Epoch 25/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5059 - val_loss: 0.2280
# Epoch 26/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.5089 - val_loss: 0.1650
# Epoch 27/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3800 - val_loss: 0.1347
# Epoch 28/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4010 - val_loss: 0.1818
# Epoch 29/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3917 - val_loss: 0.1140
# Epoch 30/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3381 - val_loss: 0.2155
# Epoch 31/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4017 - val_loss: 0.1494
# Epoch 32/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3513 - val_loss: 0.1335
# Epoch 33/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.4047 - val_loss: 0.0887
# Epoch 34/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3622 - val_loss: 0.0895
# Epoch 35/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3755 - val_loss: 0.0882
# Epoch 36/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.3346 - val_loss: 0.0976
# Epoch 37/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.4265 - val_loss: 0.0795
# Epoch 38/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.3658 - val_loss: 0.0845
# Epoch 39/75
# 22/22 [==============================] - 0s 19ms/step - loss: 0.3758 - val_loss: 0.1144
# Epoch 40/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.4270 - val_loss: 0.0806
# Epoch 41/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3431 - val_loss: 0.1485
# Epoch 42/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3958 - val_loss: 0.1050
# Epoch 43/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3371 - val_loss: 0.1121
# Epoch 44/75
# 22/22 [==============================] - 0s 15ms/step - loss: 0.3349 - val_loss: 0.0695
# Epoch 45/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3275 - val_loss: 0.0683
# Epoch 46/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3695 - val_loss: 0.0748
# Epoch 47/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2746 - val_loss: 0.1101
# Epoch 48/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3110 - val_loss: 0.0653
# Epoch 49/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3789 - val_loss: 0.0636
# Epoch 50/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2921 - val_loss: 0.0820
# Epoch 51/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3594 - val_loss: 0.0896
# Epoch 52/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3088 - val_loss: 0.0651
# Epoch 53/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3296 - val_loss: 0.1984
# Epoch 54/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3019 - val_loss: 0.0694
# Epoch 55/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3099 - val_loss: 0.0608
# Epoch 56/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3067 - val_loss: 0.0622
# Epoch 57/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3128 - val_loss: 0.0554
# Epoch 58/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3070 - val_loss: 0.0617
# Epoch 59/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3261 - val_loss: 0.0540
# Epoch 60/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3079 - val_loss: 0.0587
# Epoch 61/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2717 - val_loss: 0.0597
# Epoch 62/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.2562 - val_loss: 0.0652
# Epoch 63/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2827 - val_loss: 0.1298
# Epoch 64/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.3204 - val_loss: 0.0480
# Epoch 65/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3075 - val_loss: 0.0467
# Epoch 66/75
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3020 - val_loss: 0.0491
# Epoch 67/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2734 - val_loss: 0.0904
# Epoch 68/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2652 - val_loss: 0.0472
# Epoch 69/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.2707 - val_loss: 0.0737
# Epoch 70/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3283 - val_loss: 0.0546
# Epoch 71/75
# 22/22 [==============================] - 0s 18ms/step - loss: 0.2746 - val_loss: 0.0425
# Epoch 72/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2606 - val_loss: 0.0487
# Epoch 73/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2952 - val_loss: 0.0460
# Epoch 74/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.2612 - val_loss: 0.0413
# Epoch 75/75
# 22/22 [==============================] - 0s 17ms/step - loss: 0.3507 - val_loss: 0.0376

# %%
predicted_test_y = regressor.predict(X_test_all)

# %%
RNN_mse = metrics.mean_absolute_error(predicted_test_y, y_test_all)
RNN_rmse = metrics.mean_squared_error(predicted_test_y, y_test_all, squared=False)
RNN_r2 = metrics.r2_score(predicted_test_y, y_test_all)
RNN_acc = '-'

print(f'MSE = {RNN_mse}, RMSE = {RNN_rmse}, R2 = {RNN_r2}, accuracy = {RNN_acc}')
RNN_scores = {'model': 'Stochastic Gradient Descent', 'MSE':RNN_mse, 'RMSE':RNN_rmse, 'R2':RNN_r2, 'accuracy':RNN_acc}
# Out:
# MSE = 0.1522812298839054, RMSE = 0.20400154901166062, R2 = 0.8045277770589603, accuracy = -

# %%
true = df_rolled['mean_mood'].loc[X_test_dfid.index[0]:].values.tolist()

# %%
import matplotlib.pyplot as plt
z= df_rolled.loc[X_test_dfid.index[0]:].date

plt.plot(z,regressor.predict(X[len_2:]), label = "Predicted mood ")
plt.plot(z, true, label = "True mood")
user = df.id.unique().tolist()[-1]
plt.title(f'RNN LSTM model - User {user} - Test set')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# scores per user
mae = []
rmse = []
r2 = []
for i, item in enumerate(X_test_user):
    user = list(item.keys())[0]
    X_user = np.array(list(item.values())[0])
    Y_user = np.array(list(y_test_user[i].values())[0])

    mae.append(metrics.mean_absolute_error(regressor.predict(X_user), Y_user))
    rmse.append(metrics.mean_squared_error(regressor.predict(X_user), Y_user, squared=False)) 
    r2.append(metrics.r2_score(regressor.predict(X_user), Y_user))
    
scores_r = {'mae':mae, 'rmse':rmse, 'r2':r2}
scores_r
# Out:
# C:\Users\julia\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:682: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# {'mae': [0.21533956641242646,
#   0.35828983972943035,
#   0.09841167661878832,
#   0.11227764629182335,
#   0.06218145007178921,
#   0.1858997199648904,
#   0.16411096311750883,
#   0.05000938688005707,
#   0.4812470299857008,
#   0.37397567279755045,
#   0.2757393027411565,
#   0.04826499923827162,
#   0.13992487993189892,
#   0.06537162235804968,
#   0.0477294308798657,
#   0.03565794990176272,
#   0.2892981279463993,
#   0.10473148903879156,
#   0.06357255511813609,
#   0.15178728255014573,
#   0.03997181824275464,
#   0.11011030055858544,
#   0.1189636548360189,
#   0.2626606123788012,
#   0.021763099564445776,
#   0.11873238245646107,
#   0.17485791160946795],
#  'rmse': [0.2163856947168798,
#   0.4162840424537269,
#   0.11603743016168068,
#   0.126606366594043,
#   0.09904696597420459,
#   0.24585891706565066,
#   0.20231635588533511,
#   0.06344993041564306,
#   0.48369687161472635,
#   0.39600626659063454,
#   0.30116561776303213,
#   0.06091040873625996,
#   0.16314314575063515,
#   0.07871898872892652,
#   0.04965582501390951,
#   0.04309294594053306,
#   0.30537323718395193,
#   0.11181158280236335,
#   0.06357255511813609,
#   0.1896768968687137,
#   0.04227977686773336,
#   0.11492319232634078,
#   0.13640983701078252,
#   0.26357205370998454,
#   0.02232640895498279,
#   0.12091826203199951,
#   0.18293180219768748],
#  'r2': [-22.71119680687519,
#   -11.483123728272483,
#   -19.126327416543358,
#   -3.105579777948961,
#   -62387.35200177213,
#   -9.069943794083843,
#   -1.2732792642893047,
#   -2.0921659817337526,
#   -41.36563145112249,
#   -11.984270497519443,
#   -0.5633923355592243,
#   -1.5260490542599392,
#   -0.4410508095729382,
#   -18.17959701788121,
#   -0.8203686612421976,
#   -3.2342851520384706,
#   -5.136250719123689,
#   -0.424646619506573,
#   nan,
#   -3.6200597085508157,
#   -1.2621443089772022,
#   -43.58363039591247,
#   -24.949651408296525,
#   -168.24021898085638,
#   -15.213141461195804,
#   -11.547156620158566,
#   -0.5382884023016714]}
